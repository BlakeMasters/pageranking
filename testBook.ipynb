# %%
import time
import csv
import re
import networkx as nx
import numpy as np

class GraphParser:
    def __init__(self, file_path, dataset_type):
        """
        Initializes the parser with the dataset type and file path.

        :param file_path: Path to the CSV file.
        :param dataset_type: Type of dataset (e.g., "NCAA-FOOTBALL", "DOLPHINS", "LES-MISERABLES").
        """
        self.file_path = file_path
        self.dataset_type = dataset_type

    def clean_numeric_value(self, value):
        """ Strips non-digit characters and converts to integer. """
        return int(re.sub(r'\D', '', value)) if re.search(r'\d', value) else 0

    def parse_csv(self):
        """ Parses the CSV file and returns a list of edges based on dataset type. """
        edges = []
        with open(self.file_path, newline='', encoding='utf-8') as csvfile:
            reader = csv.reader(csvfile)
            for row in reader:
                row = [item.strip() for item in row if item.strip()]  # Remove extra whitespace

                if self.dataset_type == "NCAA-FOOTBALL":
                    self.process_ncaa_football(row, edges)
                elif self.dataset_type == "LES-MISERABLES":
                    self.process_les_miserables(row, edges)
                else:
                    self.process_generic_graph(row, edges)

        return edges

    def process_ncaa_football(self, row, edges):
        """ Processes NCAA-FOOTBALL dataset format. """
        if len(row) < 4:
            return

        team1, score1, team2, score2 = row[:4]
        overtime = row[4] if len(row) > 4 else None

        score1 = self.clean_numeric_value(score1)
        score2 = self.clean_numeric_value(score2)

        # In NCAA-FOOTBALL, the winning team is determined by score.
        # We create an edge from the losing team to the winning team so that the winner gets PageRank credit.
        if score1 > score2:
            edges.append((team2, score2, team1, score1, overtime))
        else:
            edges.append((team1, score1, team2, score2, overtime))

    def process_les_miserables(self, row, edges):
        """ Processes LES-MISERABLES dataset format. """
        if len(row) != 4:
            return

        node1, label, node2, zero_value = row
        label = self.clean_numeric_value(label)
        zero_value = self.clean_numeric_value(zero_value)

        edges.append((node1, label, node2, zero_value))

    def process_generic_graph(self, row, edges):
        """ Processes generic graph datasets (e.g., DOLPHINS, KARATE) """
        if len(row) < 4:
            return

        node1, value1, node2, value2 = row[:4]
        value1 = self.clean_numeric_value(value1)
        value2 = self.clean_numeric_value(value2)

        edges.append((node1, value1, node2, value2))


class PageRank:
    def __init__(self, graph, epsilon=1e-6, d=0.85, max_iter=100):
        """
        Initializes the PageRank instance.
        :param graph: A NetworkX graph (preferably a DiGraph for directed data).
        :param epsilon: Convergence threshold.
        :param d: Damping factor.
        :param max_iter: Maximum number of iterations.
        """
        self.graph = graph
        self.epsilon = epsilon
        self.d = d
        self.max_iter = max_iter
        self.rank = {}  # Dictionary to store the final PageRank scores

    def compute_pagerank_matrix_no_transpose(self):
        """
        Computes PageRank using a matrix-based (vectorized) approach without transposing.
        We build a column-stochastic transition matrix A such that:
           A[i, j] = 1/outdeg(j) if there is an edge from node j to node i.
        Dangling nodes (with no out-links) are handled separately.
        
        :returns: (iterations, rank) where iterations is the number of iterations run and rank is a dictionary of PageRank scores.
        """
        nodes = list(self.graph.nodes())
        N = len(nodes)
        if N == 0:
            return 0, {}
        
        # Create mapping from node to index.
        index = {node: i for i, node in enumerate(nodes)}
        
        # Build a column-stochastic transition matrix A.
        A = np.zeros((N, N))
        dangling = np.zeros(N, dtype=bool)
        for node in nodes:
            j = index[node]  # column index for the source node
            out_deg = self.graph.out_degree(node)
            if out_deg == 0:
                dangling[j] = True
            else:
                for succ in self.graph.successors(node):
                    i = index[succ]
                    A[i, j] = 1.0 / out_deg
        
        # Initialize the PageRank vector uniformly.
        pr = np.ones(N) / N
        iterations = 0
        
        while iterations < self.max_iter:
            old_pr = pr.copy()
            # Compute dangling contribution.
            dangling_sum = old_pr[dangling].sum()
            # Update without transposing (since A is column-stochastic).
            pr = (1 - self.d) / N + self.d * (A.dot(old_pr) + dangling_sum / N)
            # Convergence check using the L1 norm.
            if np.linalg.norm(pr - old_pr, ord=1) < self.epsilon:
                break
            iterations += 1
        
        # Map the PageRank vector back to node labels.
        pr_dict = {node: pr[index[node]] for node in nodes}
        self.rank = pr_dict
        return iterations, pr_dict

# %%
parser = GraphParser("data/NCAA_football.csv", "NCAA-FOOTBALL")
edges = parser.parse_csv()
for edge in edges[:10]:  # Print first 10 edges
    print(edge)
# Out:
# ('"Northeastern"', 14, 'Ball State', 48, None)
# ('"UTEP"', 17, 'Buffalo', 42, None)
# ('"Eastern Illinois"', 12, 'Central Michigan', 31, None)
# ('"Upper Iowa"', 13, 'Drake', 17, None)
# ('"Indiana State"', 0, 'Eastern Michigan', 52, None)
# ('"East Central Oklahoma"', 14, 'Sam Houston State', 58, None)
# ('"Southwest Baptist"', 28, 'Southeast Missouri State', 35, '"(OT)"')
# ('"Shorter"', 0, 'Western Carolina', 35, None)
# ('"Hofstra"', 3, 'Connecticut', 35, None)
# ('"Jacksonville State"', 14, 'Georgia Tech', 41, None)

# %%
if __name__ == "__main__":
    # For testing purposes, we set filename and dataset type.
    filename = "data/NCAA_football.csv"
    dataset_type = "NCAA-FOOTBALL"

    # Time reading/parsing the file and constructing the graph.
    start_read = time.time()
    parser = GraphParser(filename, dataset_type)
    edges = parser.parse_csv()

    # Build a directed graph from the parsed edges.
    # For NCAA-FOOTBALL, each edge is stored as (loser, score, winner, score, overtime).
    G = nx.DiGraph()
    for edge in edges:
        if dataset_type == "NCAA-FOOTBALL":
            winner, _, loser, _, _ = edge
            G.add_edge(winner, loser)#(winner, loser)(loser,winner)
        else:
            node1, _, node2, _ = edge
            G.add_edge(node1, node2)
    end_read = time.time()
    read_time = end_read - start_read

    nx_pr = nx.pagerank(G, alpha=0.95)
    sorted_nx_pr = sorted(nx_pr.items(), key=lambda item: item[1], reverse=True)
    print("NX PageRank:")
    for pos, (node, score) in enumerate(sorted_nx_pr, 1):
        print(f"{pos}: {node} -> {score}")
    

    # Compute PageRank using the matrix-based (transposed) method and time the process.
    pagerank_instance = PageRank(G, epsilon=1e-8, d=0.95, max_iter=100)
    start_process = time.time()
    iterations, pr = pagerank_instance.compute_pagerank_matrix_no_transpose()
    end_process = time.time()
    processing_time = end_process - start_process

    # Sort nodes by PageRank score in descending order and print results.
    sorted_pr = sorted(pr.items(), key=lambda item: item[1], reverse=True)
    for rank_position, (node, score) in enumerate(sorted_pr, 1):
        print(f"{rank_position} {node} with pagerank: {score}")

    print(f"\nRead time: {read_time:.6f} seconds")
    print(f"Processing time: {processing_time:.6f} seconds")
    print(f"Iterations: {iterations}")
# Out:
# NX PageRank:
# 1: North Dakota -> 0.005297782589965389
# 2: Weber State -> 0.005235289437575296
# 3: Montana -> 0.005164984641136441
# 4: South Dakota -> 0.004862460971611673
# 5: Northwestern State -> 0.0046059786586773325
# 6: Florida -> 0.004436726370954163
# 7: Iona -> 0.0044328205489297815
# 8: Richmond -> 0.004373365258114208
# 9: Utah -> 0.004339948780794504
# 10: Oklahoma -> 0.004269249456878441
# 11: Central Arkansas -> 0.004256190597382783
# 12: Sacred Heart -> 0.004206756304488348
# 13: Savannah State -> 0.0042049809308409005
# 14: Texas Tech -> 0.004159886440195777
# 15: Texas -> 0.004117750905629728
# 16: South Carolina State -> 0.004081730546960439
# 17: Grambling State -> 0.004081730546960439
# 18: James Madison -> 0.004054389792789773
# 19: Bryant University -> 0.004050523423513114
# 20: Liberty -> 0.003972367530277777
# 21: Mississippi -> 0.003971933550052845
# 22: TCU -> 0.003942462347505244
# 23: Drake -> 0.003923761745085482
# 24: Samford -> 0.003915555573559509
# 25: USC -> 0.003898196364562262
# 26: McNeese State -> 0.0037050357117201557
# 27: Tennessee-Martin -> 0.0036668454519262093
# 28: Oregon State -> 0.0036508276363514764
# 29: Prairie View A&M -> 0.0036260513107826764
# 30: Tulsa -> 0.0036213564338038757
# 31: New Hampshire -> 0.0035852571696391436
# 32: San Diego -> 0.003580049406939969
# 33: Appalachian State -> 0.0035783529387879657
# 34: Northern Iowa -> 0.003469384449582513
# 35: Villanova -> 0.003463742706658407
# 36: Jacksonville -> 0.003449855339460609
# 37: Butler -> 0.0034394398140622597
# 38: Sacramento State -> 0.0034329301106882917
# 39: Texas State -> 0.0034225145852899426
# 40: Alabama -> 0.0033795505430217533
# 41: Virginia Tech -> 0.0033404923227779455
# 42: Furman -> 0.003323172566528418
# 43: Brown -> 0.0033118496279324863
# 44: Boise State -> 0.0033092851993306196
# 45: Dayton -> 0.0032675836449895033
# 46: Cincinnati -> 0.0032458846337429436
# 47: Penn State -> 0.003241544831493631
# 48: Presbyterian -> 0.0032220157213717266
# 49: Georgia Tech -> 0.003193373026526268
# 50: West Virginia -> 0.003144333261109042
# 51: Stephen F. Austin -> 0.003130879874136174
# 52: Georgia -> 0.003097029416591541
# 53: Texas Southern -> 0.0030840100098436045
# 54: Jackson State -> 0.0030427818884751403
# 55: Harvard -> 0.0030384420862258287
# 56: Ball State -> 0.003004591628681195
# 57: Pittsburgh -> 0.0029972139648573645
# 58: Albany -> 0.002993347595580704
# 59: Iowa -> 0.002988100380133809
# 60: Ohio State -> 0.0029698732106866986
# 61: Southern Illinois -> 0.0029668353491121803
# 62: Maine -> 0.0029594576852883503
# 63: Northern Arizona -> 0.002949081612637722
# 64: Missouri -> 0.002914757722120436
# 65: Colgate -> 0.0029017383153724994
# 66: Murray State -> 0.0028987004537979815
# 67: East Carolina -> 0.0028952286119985314
# 256 Northern Colorado with pagerank: 0.0012511385849459178
# 257 "Northeastern" with pagerank: 0.001151675683912344
# 258 "UTEP" with pagerank: 0.001151675683912344
# 259 "Eastern Illinois" with pagerank: 0.001151675683912344
# 260 "Upper Iowa" with pagerank: 0.001151675683912344
# 261 "Indiana State" with pagerank: 0.001151675683912344
# 262 "East Central Oklahoma" with pagerank: 0.001151675683912344
# 263 "Southwest Baptist" with pagerank: 0.001151675683912344
# 264 "Shorter" with pagerank: 0.001151675683912344
# 265 "Hofstra" with pagerank: 0.001151675683912344
# 266 "Jacksonville State" with pagerank: 0.001151675683912344
# 267 "Miami (OH)" with pagerank: 0.001151675683912344
# 268 "Eastern Kentucky" with pagerank: 0.001151675683912344
# 269 "Charleston Southern" with pagerank: 0.001151675683912344
# 270 "Middle Tennessee State" with pagerank: 0.001151675683912344
# 271 "South Dakota State" with pagerank: 0.001151675683912344
# 272 "Lambuth" with pagerank: 0.001151675683912344
# 273 "Texas A&M-Kingsville" with pagerank: 0.001151675683912344
# 274 "Henderson State" with pagerank: 0.001151675683912344
# 275 "Austin Peay" with pagerank: 0.001151675683912344
# 276 "West Georgia" with pagerank: 0.001151675683912344
# 277 "North Carolina State" with pagerank: 0.001151675683912344
# 278 "Gardner-Webb" with pagerank: 0.001151675683912344
# 279 "Baylor" with pagerank: 0.001151675683912344
# 280 "Oregon State" with pagerank: 0.001151675683912344
# 281 "Montana-Western" with pagerank: 0.001151675683912344
# 282 "Army" with pagerank: 0.001151675683912344
# 283 "Southern Methodist" with pagerank: 0.001151675683912344
# 284 "Marist" with pagerank: 0.001151675683912344
# 285 "Appalachian State" with pagerank: 0.001151675683912344
# 286 "Youngstown State" with pagerank: 0.001151675683912344
# 287 "Akron" with pagerank: 0.001151675683912344
# 288 "Virginia Tech" with pagerank: 0.001151675683912344
# 289 "Coastal Carolina" with pagerank: 0.001151675683912344
# 290 "Pittsburgh" with pagerank: 0.001151675683912344
# 291 "Syracuse" with pagerank: 0.001151675683912344
# 292 "Western Kentucky" with pagerank: 0.001151675683912344
# 293 "Maine" with pagerank: 0.001151675683912344
# 294 "Georgia Southern" with pagerank: 0.001151675683912344
# 295 "Hawaii" with pagerank: 0.001151675683912344
# 296 "Monmouth" with pagerank: 0.001151675683912344
# 297 "Campbell" with pagerank: 0.001151675683912344
# 298 "Southern Utah" with pagerank: 0.001151675683912344
# 299 "Ohio" with pagerank: 0.001151675683912344
# 300 "Adams State" with pagerank: 0.001151675683912344
# 301 "Virginia" with pagerank: 0.001151675683912344
# 302 "Villanova" with pagerank: 0.001151675683912344
# 303 "Michigan" with pagerank: 0.001151675683912344
# 304 "Washington State" with pagerank: 0.001151675683912344
# 305 "Towson" with pagerank: 0.001151675683912344
# 306 "Delaware" with pagerank: 0.001151675683912344
# 307 "UAB" with pagerank: 0.001151675683912344
# 308 "Western Oregon" with pagerank: 0.001151675683912344
# 309 "Illinois State" with pagerank: 0.001151675683912344
# 310 "Bryant University" with pagerank: 0.001151675683912344
# 311 "Northern Iowa" with pagerank: 0.001151675683912344
# 312 "Alabama State" with pagerank: 0.001151675683912344
# 313 "Albany" with pagerank: 0.001151675683912344
# 314 "McNeese State" with pagerank: 0.001151675683912344
# 315 "New Mexico" with pagerank: 0.001151675683912344
# 316 "Alcorn State" with pagerank: 0.001151675683912344
# 317 "Texas College" with pagerank: 0.001151675683912344
# 318 "Johnson Smith" with pagerank: 0.001151675683912344
# 319 "Virginia State" with pagerank: 0.001151675683912344
# 320 "Assumption" with pagerank: 0.001151675683912344
# 321 "Colgate" with pagerank: 0.001151675683912344
# 322 "South Carolina State" with pagerank: 0.001151675683912344
# 323 "Mississippi State" with pagerank: 0.001151675683912344
# 324 "Chattanooga" with pagerank: 0.001151675683912344
# 325 "Louisiana-Monroe" with pagerank: 0.001151675683912344
# 326 "Florida Atlantic" with pagerank: 0.001151675683912344
# 327 "Eastern Washington" with pagerank: 0.001151675683912344
# 328 "Tennessee-Martin" with pagerank: 0.001151675683912344
# 329 "Western Illinois" with pagerank: 0.001151675683912344
# 330 "Northern Illinois" with pagerank: 0.001151675683912344
# 331 "Memphis" with pagerank: 0.001151675683912344
# 332 "James Madison" with pagerank: 0.001151675683912344
# 333 "Western Michigan" with pagerank: 0.001151675683912344
# 334 "Mars Hill" with pagerank: 0.001151675683912344
# 335 "Southern University" with pagerank: 0.001151675683912344
# 336 "Angelo State" with pagerank: 0.001151675683912344
# 337 "Alabama A&M" with pagerank: 0.001151675683912344
# 338 "Arkansas-Pine Bluff" with pagerank: 0.001151675683912344
# 339 "Elon" with pagerank: 0.001151675683912344
# 340 "North Greenville" with pagerank: 0.001151675683912344
# 341 "Southern Virginia" with pagerank: 0.001151675683912344
# 342 "Texas A&M-Commerce" with pagerank: 0.001151675683912344
# 343 "Savannah State" with pagerank: 0.001151675683912344
# 344 "Louisiana-Lafayette" with pagerank: 0.001151675683912344
# 345 "Langston" with pagerank: 0.001151675683912344
# 346 "Webber International" with pagerank: 0.001151675683912344
# 347 "Presbyterian" with pagerank: 0.001151675683912344
# 348 "Florida International" with pagerank: 0.001151675683912344
# 349 "Texas A&M" with pagerank: 0.001151675683912344
# 350 "North Texas" with pagerank: 0.001151675683912344
# 351 "Kent State" with pagerank: 0.001151675683912344
# 352 "Clemson" with pagerank: 0.001151675683912344
# 353 "UC Davis" with pagerank: 0.001151675683912344
# 354 "Michigan State" with pagerank: 0.001151675683912344
# 355 "Idaho State" with pagerank: 0.001151675683912344
# 356 "St. Ambrose" with pagerank: 0.001151675683912344
# 357 "Texas Southern" with pagerank: 0.001151675683912344
# 358 "Illinois" with pagerank: 0.001151675683912344
# 359 "Humboldt State" with pagerank: 0.001151675683912344
# 360 "Grambling State" with pagerank: 0.001151675683912344
# 361 "San Diego State" with pagerank: 0.001151675683912344
# 362 "Utah State" with pagerank: 0.001151675683912344
# 363 "Idaho" with pagerank: 0.001151675683912344
# 364 "Washington" with pagerank: 0.001151675683912344
# 365 "Northern Arizona" with pagerank: 0.001151675683912344
# 366 "Jackson State" with pagerank: 0.001151675683912344
# 367 "Louisville" with pagerank: 0.001151675683912344
# 368 "North Carolina Central" with pagerank: 0.001151675683912344
# 369 "Central State" with pagerank: 0.001151675683912344
# 370 "Colorado State" with pagerank: 0.001151675683912344
# 371 "Rutgers" with pagerank: 0.001151675683912344
# 372 "Tennessee" with pagerank: 0.001151675683912344
# 373 "Valparaiso" with pagerank: 0.001151675683912344
# 374 "Florida A&M" with pagerank: 0.001151675683912344
# 375 "Missouri State" with pagerank: 0.001151675683912344
# 376 "South Carolina" with pagerank: 0.001151675683912344
# 377 "Wagner" with pagerank: 0.001151675683912344
# 378 "Navy" with pagerank: 0.001151675683912344
# 379 "Marshall" with pagerank: 0.001151675683912344
# 380 "Boston College" with pagerank: 0.001151675683912344
# 381 "Temple" with pagerank: 0.001151675683912344
# 382 "Northern Colorado" with pagerank: 0.001151675683912344
# 383 "Livingstone" with pagerank: 0.001151675683912344
# 384 "Eastern Michigan" with pagerank: 0.001151675683912344
# 385 "Southern Miss" with pagerank: 0.001151675683912344
# 386 "San Jose State" with pagerank: 0.001151675683912344
# 387 "Drake" with pagerank: 0.001151675683912344
# 388 "Holy Cross" with pagerank: 0.001151675683912344
# 389 "Morehead State" with pagerank: 0.001151675683912344
# 390 "Bentley College" with pagerank: 0.001151675683912344
# 391 "Albion" with pagerank: 0.001151675683912344
# 392 "Southern Connecticut State" with pagerank: 0.001151675683912344
# 393 "Delaware Valley" with pagerank: 0.001151675683912344
# 394 "Furman" with pagerank: 0.001151675683912344
# 395 "Fayetteville State" with pagerank: 0.001151675683912344
# 396 "St. Francis (PA)" with pagerank: 0.001151675683912344
# 397 "St. Cloud State" with pagerank: 0.001151675683912344
# 398 "Stony Brook" with pagerank: 0.001151675683912344
# 399 "Central Michigan" with pagerank: 0.001151675683912344
# 400 "Cincinnati" with pagerank: 0.001151675683912344
# 401 "Mississippi" with pagerank: 0.001151675683912344
# 402 "Sacramento State" with pagerank: 0.001151675683912344
# 403 "Tennessee Tech" with pagerank: 0.001151675683912344
# 404 "Citadel" with pagerank: 0.001151675683912344
# 405 "Jacksonville" with pagerank: 0.001151675683912344
# 406 "Wyoming" with pagerank: 0.001151675683912344
# 407 "Richmond" with pagerank: 0.001151675683912344
# 408 "West Virginia" with pagerank: 0.001151675683912344
# 409 "Stillman" with pagerank: 0.001151675683912344
# 410 "South Dakota" with pagerank: 0.001151675683912344
# 411 "Baker University" with pagerank: 0.001151675683912344
# 412 "Western Carolina" with pagerank: 0.001151675683912344
# 413 "Norfolk State" with pagerank: 0.001151675683912344
# 414 "Morgan State" with pagerank: 0.001151675683912344
# 415 "William & Mary" with pagerank: 0.001151675683912344
# 416 "Buffalo" with pagerank: 0.001151675683912344
# 417 "Cumberland University" with pagerank: 0.001151675683912344
# 418 "Duquesne" with pagerank: 0.001151675683912344
# 419 "Rhode Island" with pagerank: 0.001151675683912344
# 420 "Tusculum" with pagerank: 0.001151675683912344
# 421 "Winston-Salem" with pagerank: 0.001151675683912344
# 422 "Benedict" with pagerank: 0.001151675683912344
# 423 "Davidson" with pagerank: 0.001151675683912344
# 424 "New Mexico Highlands" with pagerank: 0.001151675683912344
# 425 "Southeast Missouri State" with pagerank: 0.001151675683912344
# 426 "Tulane" with pagerank: 0.001151675683912344
# 427 "UCF" with pagerank: 0.001151675683912344
# 428 "Hampton" with pagerank: 0.001151675683912344
# 429 "Murray State" with pagerank: 0.001151675683912344
# 430 "Duke" with pagerank: 0.001151675683912344
# 431 "Northwestern State" with pagerank: 0.001151675683912344
# 432 "Southeastern Louisiana" with pagerank: 0.001151675683912344
# 433 "Glenville State" with pagerank: 0.001151675683912344
# 434 "Maryland" with pagerank: 0.001151675683912344
# 435 "Central Connecticut State" with pagerank: 0.001151675683912344
# 436 "Faulkner" with pagerank: 0.001151675683912344
# 437 "Stephen F. Austin" with pagerank: 0.001151675683912344
# 438 "Houston" with pagerank: 0.001151675683912344
# 439 "Quincy" with pagerank: 0.001151675683912344
# 440 "Montana State" with pagerank: 0.001151675683912344
# 441 "Louisiana Tech" with pagerank: 0.001151675683912344
# 442 "Bowling Green" with pagerank: 0.001151675683912344
# 443 "Miami (FL)" with pagerank: 0.001151675683912344
# 444 "Delta State" with pagerank: 0.001151675683912344
# 445 "Texas State" with pagerank: 0.001151675683912344
# 446 "UNLV" with pagerank: 0.001151675683912344
# 447 "Azusa Pacific" with pagerank: 0.001151675683912344
# 448 "Nevada" with pagerank: 0.001151675683912344
# 449 "Cal Poly" with pagerank: 0.001151675683912344
# 450 "Toledo" with pagerank: 0.001151675683912344
# 451 "Stanford" with pagerank: 0.001151675683912344
# 452 "Weber State" with pagerank: 0.001151675683912344
# 453 "Howard" with pagerank: 0.001151675683912344
# 454 "Concordia College" with pagerank: 0.001151675683912344
# 455 "Kansas" with pagerank: 0.001151675683912344
# 456 "California" with pagerank: 0.001151675683912344
# 457 "Rhodes" with pagerank: 0.001151675683912344
# 458 "Southern Illinois" with pagerank: 0.001151675683912344
# 459 "Iowa State" with pagerank: 0.001151675683912344
# 460 "Lehigh" with pagerank: 0.001151675683912344
# 461 "Butler" with pagerank: 0.001151675683912344
# 462 "Fordham" with pagerank: 0.001151675683912344
# 463 "Robert Morris" with pagerank: 0.001151675683912344
# 464 "Iona" with pagerank: 0.001151675683912344
# 465 "Merrimack" with pagerank: 0.001151675683912344
# 466 "Wisconsin-La Crosse" with pagerank: 0.001151675683912344
# 467 "Delaware State" with pagerank: 0.001151675683912344
# 468 "Concordia University (WI)" with pagerank: 0.001151675683912344
# 469 "North Dakota State" with pagerank: 0.001151675683912344
# 470 "Purdue" with pagerank: 0.001151675683912344
# 471 "UCLA" with pagerank: 0.001151675683912344
# 472 "Massachusetts" with pagerank: 0.001151675683912344
# 473 "Georgia Tech" with pagerank: 0.001151675683912344
# 474 "North Carolina A&T" with pagerank: 0.001151675683912344
# 475 "Bethune-Cookman" with pagerank: 0.001151675683912344
# 476 "Southern Oregon" with pagerank: 0.001151675683912344
# 477 "West Chester" with pagerank: 0.001151675683912344
# 478 "Georgetown" with pagerank: 0.001151675683912344
# 479 "Samford" with pagerank: 0.001151675683912344
# 480 "New Mexico State" with pagerank: 0.001151675683912344
# 481 "Rice" with pagerank: 0.001151675683912344
# 482 "Arkansas State" with pagerank: 0.001151675683912344
# 483 "William Penn" with pagerank: 0.001151675683912344
# 484 "Lenoir-Rhyne" with pagerank: 0.001151675683912344
# 485 "Mississippi Valley State" with pagerank: 0.001151675683912344
# 486 "Virginia Military Institute" with pagerank: 0.001151675683912344
# 487 "Shaw" with pagerank: 0.001151675683912344
# 488 "Ohio State" with pagerank: 0.001151675683912344
# 489 "Arizona" with pagerank: 0.001151675683912344
# 490 "Dixie State" with pagerank: 0.001151675683912344
# 491 "Portland State" with pagerank: 0.001151675683912344
# 492 "Arizona State" with pagerank: 0.001151675683912344
# 493 "Fresno State" with pagerank: 0.001151675683912344
# 494 "Kansas State" with pagerank: 0.001151675683912344
# 495 "Troy" with pagerank: 0.001151675683912344
# 496 "East Carolina" with pagerank: 0.001151675683912344
# 497 "Iowa" with pagerank: 0.001151675683912344
# 498 "Arkansas" with pagerank: 0.001151675683912344
# 499 "Columbia" with pagerank: 0.001151675683912344
# 500 "Princeton" with pagerank: 0.001151675683912344
# 501 "Dartmouth" with pagerank: 0.001151675683912344
# 502 "Chowan" with pagerank: 0.001151675683912344
# 503 "Culver-Stockton" with pagerank: 0.001151675683912344
# 504 "Oregon" with pagerank: 0.001151675683912344
# 505 "Notre Dame" with pagerank: 0.001151675683912344
# 506 "North Carolina" with pagerank: 0.001151675683912344
# 507 "Pennsylvania" with pagerank: 0.001151675683912344
# 508 "Air Force" with pagerank: 0.001151675683912344
# 509 "Bucknell" with pagerank: 0.001151675683912344
# 510 "Florida State" with pagerank: 0.001151675683912344
# 511 "Sam Houston State" with pagerank: 0.001151675683912344
# 512 "Indiana" with pagerank: 0.001151675683912344
# 513 "Wofford" with pagerank: 0.001151675683912344
# 514 "Auburn" with pagerank: 0.001151675683912344
# 515 "Nicholls State" with pagerank: 0.001151675683912344
# 516 "Western Washington" with pagerank: 0.001151675683912344
# 517 "Central Methodist" with pagerank: 0.001151675683912344
# 518 "USC" with pagerank: 0.001151675683912344
# 519 "Minnesota" with pagerank: 0.001151675683912344
# 520 "Florida" with pagerank: 0.001151675683912344
# 521 "Harvard" with pagerank: 0.001151675683912344
# 522 "Yale" with pagerank: 0.001151675683912344
# 523 "Pace" with pagerank: 0.001151675683912344
# 524 "Dayton" with pagerank: 0.001151675683912344
# 525 "Missouri S&T" with pagerank: 0.001151675683912344
# 526 "Central Washington" with pagerank: 0.001151675683912344
# 527 "Wisconsin" with pagerank: 0.001151675683912344
# 528 "Colorado" with pagerank: 0.001151675683912344
# 529 "Wake Forest" with pagerank: 0.001151675683912344
# 530 "Tennessee State" with pagerank: 0.001151675683912344
# 531 "Morehouse" with pagerank: 0.001151675683912344
# 532 "TCU" with pagerank: 0.001151675683912344
# 533 "Southeastern Oklahoma" with pagerank: 0.001151675683912344
# 534 "North Dakota" with pagerank: 0.001151675683912344
# 535 "Central Arkansas" with pagerank: 0.001151675683912344
# 536 "Georgia" with pagerank: 0.001151675683912344
# 537 "Nebraska" with pagerank: 0.001151675683912344
# 538 "Carthage" with pagerank: 0.001151675683912344
# 539 "South Florida" with pagerank: 0.001151675683912344
# 540 "Brown" with pagerank: 0.001151675683912344
# 541 "Stonehill" with pagerank: 0.001151675683912344
# 542 "Lafayette" with pagerank: 0.001151675683912344
# 543 "Clark Atlanta" with pagerank: 0.001151675683912344
# 544 "Montana" with pagerank: 0.001151675683912344
# 545 "Kentucky" with pagerank: 0.001151675683912344
# 546 "Connecticut" with pagerank: 0.001151675683912344
# 547 "Prairie View A&M" with pagerank: 0.001151675683912344
# 548 "Oklahoma" with pagerank: 0.001151675683912344
# 549 "Cornell" with pagerank: 0.001151675683912344
# 550 "New Hampshire" with pagerank: 0.001151675683912344
# 551 "Vanderbilt" with pagerank: 0.001151675683912344
# 552 "Northwestern" with pagerank: 0.001151675683912344
# 553 "Kentucky Wesleyan" with pagerank: 0.001151675683912344
# 554 "Missouri" with pagerank: 0.001151675683912344
# 555 "LSU" with pagerank: 0.001151675683912344
# 556 "Brigham Young" with pagerank: 0.001151675683912344
# 557 "Sacred Heart" with pagerank: 0.001151675683912344
# 558 "Liberty" with pagerank: 0.001151675683912344
# 559 "San Diego" with pagerank: 0.001151675683912344
# 560 "Oklahoma State" with pagerank: 0.001151675683912344
# 561 "Lincoln (MO)" with pagerank: 0.001151675683912344
# 562 "Edward Waters" with pagerank: 0.001151675683912344
# 563 "Tulsa" with pagerank: 0.001151675683912344
# 564 "Texas" with pagerank: 0.001151675683912344
# 565 "Penn State" with pagerank: 0.001151675683912344
# 566 "Texas Tech" with pagerank: 0.001151675683912344
# 567 "Tuskegee" with pagerank: 0.001151675683912344
# 568 "Ball State" with pagerank: 0.001151675683912344
# 569 "Alabama" with pagerank: 0.001151675683912344
# 570 "Boise State" with pagerank: 0.001151675683912344
#
# Read time: 0.017230 seconds
# Processing time: 0.008002 seconds
# Iterations: 28

# %%
import time
import csv
import re
import networkx as nx
import numpy as np

class GraphParser:
    def __init__(self, file_path, dataset_type):
        self.file_path = file_path
        self.dataset_type = dataset_type

    def clean_numeric_value(self, value):
        return int(re.sub(r'\D', '', value)) if re.search(r'\d', value) else 0

    def parse_csv(self):
        edges = []
        with open(self.file_path, newline='', encoding='utf-8') as csvfile:
            reader = csv.reader(csvfile)
            for row in reader:
                row = [item.strip() for item in row if item.strip()]

                if self.dataset_type == "NCAA-FOOTBALL":
                    self.process_ncaa_football(row, edges)
                elif self.dataset_type == "LES-MISERABLES":
                    self.process_les_miserables(row, edges)
                else:
                    self.process_generic_graph(row, edges)

        return edges

    def process_ncaa_football(self, row, edges):
        if len(row) < 4:
            return

        team1, score1, team2, score2 = row[:4]
        overtime = row[4] if len(row) > 4 else None

        score1 = self.clean_numeric_value(score1)
        score2 = self.clean_numeric_value(score2)
        if score1 > score2:
            edges.append((team2, score2, team1, score1, overtime))
        else:
            edges.append((team1, score1, team2, score2, overtime))

    def process_les_miserables(self, row, edges):
        if len(row) != 4:
            return
        node1, label, node2, zero_value = row
        label = self.clean_numeric_value(label)
        zero_value = self.clean_numeric_value(zero_value)
        edges.append((node1, label, node2, zero_value))

    def process_generic_graph(self, row, edges):
        if len(row) < 4:
            return
        node1, value1, node2, value2 = row[:4]
        value1 = self.clean_numeric_value(value1)
        value2 = self.clean_numeric_value(value2)
        edges.append((node1, value1, node2, value2))

class PageRank:
    def __init__(self, graph, epsilon=1e-8, d=0.85, max_iter=100):
        """
        Initializes PageRank.
        :param graph: A networkx.DiGraph.
        :param epsilon: Convergence threshold.
        :param d: Damping factor.
        :param max_iter: Maximum iterations.
        """
        self.graph = graph
        self.epsilon = epsilon
        self.d = d
        self.max_iter = max_iter
        self.rank = {}

    def compute_pagerank(self):
        """
        A[i, j] = 1 / out_degree(j)   if there is an edge from node j to node i
        returns: (iterations, rank_dict)
        """
        nodes = list(self.graph.nodes())
        N = len(nodes)
        if N == 0:
            return 0, {}
        index = {node: i for i, node in enumerate(nodes)}
        A = np.zeros((N, N))
        dangling = np.zeros(N, dtype=bool)
        for node in nodes:
            j = index[node]
            out_deg = self.graph.out_degree(node)
            if out_deg == 0:
                dangling[j] = True
            else:
                for succ in self.graph.successors(node):
                    i = index[succ]
                    A[i, j] = 1.0 / out_deg

        pr = np.ones(N) / N
        for iteration in range(self.max_iter):
            old_pr = pr.copy()
            dangling_sum = old_pr[dangling].sum()
            pr = (1 - self.d) / N + self.d * (A.dot(old_pr) + dangling_sum / N)
            if np.linalg.norm(pr - old_pr, ord=1) < self.epsilon:
                break

        pr_dict = {node: pr[index[node]] for node in nodes}
        self.rank = pr_dict
        return iteration + 1, pr_dict

if __name__ == "__main__":
    filename = "data/NCAA_football.csv"
    dataset_type = "NCAA-FOOTBALL"
    start_read = time.time()
    parser = GraphParser(filename, dataset_type)
    edges = parser.parse_csv()
    end_read = time.time()
    read_time = end_read - start_read

    G = nx.DiGraph()
    for edge in edges:
        winner, _, loser, _, _ = edge
        G.add_edge(winner, loser)

    start_process = time.time()
    nx_pr = nx.pagerank(G, alpha=0.85)
    end_process = time.time()
    nx_processing_time = end_process - start_process
    sorted_nx_pr = sorted(nx_pr.items(), key=lambda x: x[1], reverse=True)
    unsorted_nx_pr = sorted(nx_pr.items(), key=lambda x: x[1], reverse=False)

    pagerank_instance = PageRank(G, epsilon=1e-10, d=0.85, max_iter=100)
    start_process_custom = time.time()
    iterations_custom, pr_custom = pagerank_instance.compute_pagerank()
    end_process_custom = time.time()
    custom_processing_time = end_process_custom - start_process_custom
    sorted_custom_pr = sorted(pr_custom.items(), key=lambda x: x[1], reverse=True)

    print("=== NetworkX PageRank (top 10) ===")
    for i, (node, score) in enumerate(sorted_nx_pr[:10], 1):
        print(f"{i}. {node} -> {score}")

    print("\n=== Custom PageRank (top 10) ===")
    for i, (node, score) in enumerate(sorted_custom_pr[:10], 1):
        print(f"{i}. {node} -> {score}")

    print(f"\nNumber of nodes: {G.number_of_nodes()}")
    print(f"Number of edges: {G.number_of_edges()}")
    print(f"Read time: {read_time:.6f} seconds")
    print(f"NetworkX PageRank processing time: {nx_processing_time:.6f} seconds")
    print(f"Custom PageRank processing time: {custom_processing_time:.6f} seconds")
    print(f"Custom PageRank iterations: {iterations_custom}")
# Out:
# === NetworkX PageRank (top 10) ===
# 1. North Dakota -> 0.005045914837189206
# 2. Weber State -> 0.004987863753108685
# 3. Montana -> 0.004922556283518098
# 4. South Dakota -> 0.004641536262855575
# 5. Northwestern State -> 0.004403284938608435
# 6. Florida -> 0.0042460632525570235
# 7. Iona -> 0.004242435059801991
# 8. Richmond -> 0.004187205903419829
# 9. Utah -> 0.004156164698737884
# 10. Oklahoma -> 0.004090490745030627
#
# === Custom PageRank (top 10) ===
# 1. North Dakota -> 0.005045134098984914
# 2. Weber State -> 0.004987096784402064
# 3. Montana -> 0.004921804805496358
# 4. South Dakota -> 0.004640851441720289
# 5. Northwestern State -> 0.004402656629786509
# 6. Florida -> 0.0042454722361246235
# 7. Iona -> 0.004241844903963197
# 8. Richmond -> 0.004186628847728124
# 9. Utah -> 0.0041555950059025725
# 10. Oklahoma -> 0.004089936629808844
#
# Number of nodes: 570
# Number of edges: 1535
# Read time: 0.000000 seconds
# NetworkX PageRank processing time: 0.011921 seconds
# Custom PageRank processing time: 0.005152 seconds
# Custom PageRank iterations: 31

# %%
if __name__ == "__main__":
    filename = "data/dolphins.csv"  
    dataset_type = "DOLPHINS"        

    start_read = time.time()
    parser = GraphParser(filename, dataset_type)
    edges = parser.parse_csv()
    end_read = time.time()
    read_time = end_read - start_read
    G = nx.Graph()
    for edge in edges:
        #(dolphin1, val1, dolphin2, val2)
        dolphin1, _, dolphin2, _ = edge
        G.add_edge(dolphin1, dolphin2)
    
    start_process = time.time()
    G_directed = nx.DiGraph()
    for e in G.edges():
        G_directed.add_edge(e[0], e[1])
        G_directed.add_edge(e[1], e[0])
    nx_pr = nx.pagerank(G_directed, alpha=0.85)

    nx_pr = nx.pagerank(G_directed, alpha=0.85)
    end_process = time.time()
    processing_time = end_process - start_process

    pagerank_instance = PageRank(G_directed, epsilon=1e-10, d=0.85, max_iter=100)
    start_process_custom = time.time()
    iterations_custom, pr_custom = pagerank_instance.compute_pagerank()
    end_process_custom = time.time()
    custom_processing_time = end_process_custom - start_process_custom
    sorted_custom_pr = sorted(pr_custom.items(), key=lambda x: x[1], reverse=True)

    print("\n=== Custom PageRank (top 10) ===")
    for i, (node, score) in enumerate(sorted_custom_pr[:10], 1):
        print(f"{i}. {node} -> {score}")
    print(f"Custom PageRank iterations: {iterations_custom}")
    
    sorted_nx_pr = sorted(nx_pr.items(), key=lambda x: x[1], reverse=True)
    for i, (node, score) in enumerate(sorted_nx_pr[:10], 1):
        print(f"{i}. {node}: {score}")

    print(f"\nRead time: {read_time:.6f} seconds")
    print(f"Processing time: {processing_time:.6f} seconds")
# Out:
# === Custom PageRank (top 10) ===
# 1. Grin -> 0.032144492767568124
# 2. Jet -> 0.03172814043060556
# 3. Trigger -> 0.03129935689421097
# 4. Web -> 0.03009537140536281
# 5. SN4 -> 0.029875338593220523
# 6. Topless -> 0.02951420357096363
# 7. Scabs -> 0.028423069722867778
# 8. Patchback -> 0.02645855018299648
# 9. Gallatin -> 0.02615687599797234
# 10. Beescratch -> 0.024650716860371423
# Custom PageRank iterations: 86
# 1. Grin: 0.032137029718865714
# 2. Jet: 0.0317411226125807
# 3. Trigger: 0.031292342498045814
# 4. Web: 0.030108941362489344
# 5. SN4: 0.029868954502794757
# 6. Topless: 0.02950713720344268
# 7. Scabs: 0.028416738215896527
# 8. Patchback: 0.026452435542402356
# 9. Gallatin: 0.02616992597905726
# 10. Beescratch: 0.024657779163893456
#
# Read time: 0.002996 seconds
# Processing time: 0.004510 seconds

# %%
if __name__ == "__main__":
    filename = "data/lesmis.csv"       
    dataset_type = "LES-MISERABLES"

    start_read = time.time()
    parser = GraphParser(filename, dataset_type)
    edges = parser.parse_csv()
    end_read = time.time()
    read_time = end_read - start_read
    G = nx.Graph()
    for edge in edges:
        char1, label, char2, zero_value = edge
        G.add_edge(char1, char2)
    
    start_process = time.time()
    G_dir = nx.DiGraph()
    for u, v in G.edges():
        G_dir.add_edge(u, v)
        G_dir.add_edge(v, u)

    nx_pr = nx.pagerank(G_dir, alpha=0.85)
    end_process = time.time()
    processing_time = end_process - start_process

    pagerank_instance = PageRank(G_dir, epsilon=1e-10, d=0.85, max_iter=100)
    start_process_custom = time.time()
    iterations_custom, pr_custom = pagerank_instance.compute_pagerank()
    end_process_custom = time.time()
    custom_processing_time = end_process_custom - start_process_custom
    sorted_custom_pr = sorted(pr_custom.items(), key=lambda x: x[1], reverse=True)

    print("\n=== Custom PageRank (top 10) ===")
    for i, (node, score) in enumerate(sorted_custom_pr[:10], 1):
        print(f"{i}. {node} -> {score}")
    print(f"Custom PageRank iterations: {iterations_custom}")

    sorted_nx_pr = sorted(nx_pr.items(), key=lambda x: x[1], reverse=True)
    for i, (node, score) in enumerate(sorted_nx_pr[:10], 1):
        print(f"{i}. {node}: {score}")

    print(f"\nRead time: {read_time:.6f} seconds")
    print(f"Processing time: {processing_time:.6f} seconds")
# Out:
# === Custom PageRank (top 10) ===
# 1. Valjean -> 0.07543012164773534
# 2. Myriel -> 0.04277928105974448
# 3. Gavroche -> 0.03576731818311261
# 4. Marius -> 0.030894936207253653
# 5. Javert -> 0.030302735905698455
# 6. Thenardier -> 0.027926525691254794
# 7. Fantine -> 0.02702270491839203
# 8. Enjolras -> 0.02188203331961119
# 9. Cosette -> 0.020611215084313916
# 10. MmeThenardier -> 0.019501134690098298
# Custom PageRank iterations: 76
# 1. Valjean: 0.07543374445332475
# 2. Myriel: 0.04280343976075732
# 3. Gavroche: 0.03576412343161933
# 4. Marius: 0.030892701920406464
# 5. Javert: 0.03030259712717036
# 6. Thenardier: 0.027925725316528028
# 7. Fantine: 0.027022474221419405
# 8. Enjolras: 0.021879692835635844
# 9. Cosette: 0.0206109951184114
# 10. MmeThenardier: 0.019500856219565182
#
# Read time: 0.003340 seconds
# Processing time: 0.005623 seconds
